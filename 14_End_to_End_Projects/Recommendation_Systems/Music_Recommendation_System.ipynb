# %% [markdown]
# # **Music Recommendation System**

# %% [markdown]
# **Importing Dependencies**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import os
import json
from zipfile import ZipFile
import re

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from wordcloud import WordCloud
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %% [markdown]
# **Downloading Dataset from Kaggle & Extracting**

# %%
kaggle_config = json.load(open('kaggle.json'))

# %%
kaggle_config.keys()
# Out:
# dict_keys(['username', 'key'])

# %%
os.environ['KAGGLE_USERNAME'] = kaggle_config['username']
os.environ['KAGGLE_KEY'] = kaggle_config['key']

# %%
# !kaggle datasets download notshrirang/spotify-million-song-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/notshrirang/spotify-million-song-dataset
# License(s): CC0-1.0
# spotify-million-song-dataset.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !ls
# Out:
# kaggle.json  spotify-million-song-dataset.zip
# sample_data  spotify_millsongdata.csv

# %%
with ZipFile('spotify-million-song-dataset.zip', 'r') as zipObj:
    zipObj.extractall()

# %%
df = pd.read_csv("/content/spotify_millsongdata.csv")
df.shape
# Out:
# (57650, 4)

# %% [markdown]
# **Dataset Description & Information**

# %%
df.head()
# Out:
#   artist                   song                                        link  \
# 0   ABBA  Ahe's My Kind Of Girl  /a/abba/ahes+my+kind+of+girl_20598417.html
# 1   ABBA       Andante, Andante       /a/abba/andante+andante_20002708.html
# 2   ABBA         As Good As New        /a/abba/as+good+as+new_20003033.html
# 3   ABBA                   Bang                  /a/abba/bang_20598415.html
# 4   ABBA       Bang-A-Boomerang      /a/abba/bang+a+boomerang_20002668.html
#
#                                                 text
# 0  Look at her face, it's a wonderful face  \r\nA...
# 1  Take it easy with me, please  \r\nTouch me gen...
# 2  I'll never know why I had to go  \r\nWhy I had...
# 3  Making somebody happy is a question of give an...
# 4  Making somebody happy is a question of give an...

# %%
df.tail()
# Out:
#              artist           song  \
# 57645  Ziggy Marley  Good Old Days
# 57646  Ziggy Marley  Hand To Mouth
# 57647          Zwan   Come With Me
# 57648          Zwan         Desire
# 57649          Zwan      Heartsong
#
#                                               link  \
# 57645  /z/ziggy+marley/good+old+days_10198588.html
# 57646  /z/ziggy+marley/hand+to+mouth_20531167.html
# 57647           /z/zwan/come+with+me_20148981.html
# 57648                 /z/zwan/desire_20148986.html
# 57649              /z/zwan/heartsong_20148991.html
#
#                                                     text
# 57645  Irie days come on play  \r\nLet the angels fly...
# 57646  Power to the workers  \r\nMore power  \r\nPowe...
# 57647  all you need  \r\nis something i'll believe  \...
# 57648  northern star  \r\nam i frightened  \r\nwhere ...
# 57649  come in  \r\nmake yourself at home  \r\ni'm a ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57650 entries, 0 to 57649
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   artist  57650 non-null  object
#  1   song    57650 non-null  object
#  2   link    57650 non-null  object
#  3   text    57650 non-null  object
# dtypes: object(4)
# memory usage: 1.8+ MB

# %%
df.isnull().sum()
# Out:
# artist    0
# song      0
# link      0
# text      0
# dtype: int64

# %%
top_artists = df['artist'].value_counts().head(10)
print("Top 10 Artists: ")
print(top_artists)
# Out:
# Top 10 Artists:
# artist
# Donna Summer        191
# Gordon Lightfoot    189
# Bob Dylan           188
# George Strait       188
# Loretta Lynn        187
# Alabama             187
# Cher                187
# Reba Mcentire       187
# Chaka Khan          186
# Dean Martin         186
# Name: count, dtype: int64

# %% [markdown]
# **Text Feature Extraction**

# %%
df = df.sample(10000)
df = df.drop('link', axis=1).reset_index(drop=True)

# %%
df.head(10)
# Out:
#                artist                         song  \
# 0         Johnny Cash             I See A Darkness
# 1      Reo Speedwagon  I Want To Know What Love Is
# 2  Kris Kristofferson       The Eagle And The Bear
# 3                Kyla               I Feel For You
# 4          Kanye West                I'll Fly Away
# 5      Point Of Grace                      Any Way
# 6    Barbra Streisand                   I Like Him
# 7        Neil Diamond            Don't Turn Around
# 8        Idina Menzel         Better To Have Loved
# 9        Utada Hikaru                      Animato
#
#                                                 text
# 0  Well, you're my friend  \r\nAnd you can see  \...
# 1  I gotta take a little time  \r\nA little time ...
# 2  I will fight and I will die for freedom up aga...
# 3  Something inside,  \r\nMy heart,  \r\nAnd it f...
# 4  Some glad morning when this life is over  \r\n...
# 5  Setting out, what a child, my steps ahead of m...
# 6  I like him, I like him,  \r\nHow strange the f...
# 7  If you want to leave  \r\nI won't beg you to s...
# 8  Better To Have Loved  \r\nOoh  \r\nBetter To H...
# 9  Somebody out there better get this  \r\nNot ma...

# %%
df.shape
# Out:
# (10000, 3)

# %%
all_lyrics = " ".join(df['text'].dropna())
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(all_lyrics)

# %%
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title("Most common words in Lyrics")
plt.show()

# %%
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stop_words = set(stopwords.words('english'))

# %%
def preprocess_text(text):
    text = re.sub(r"[^a-zA-Z\s]", "", text)
    text = text.lower()
    tokens = word_tokenize(text)
    filtered_tokens = [word for word in tokens if word not in stop_words]
    preprocessed_text = " ".join(filtered_tokens)
    return preprocessed_text

# %%
df['processed_text'] = df['text'].apply(preprocess_text)

# %%
df.head(10)
# Out:
#                artist                         song  \
# 0         Johnny Cash             I See A Darkness
# 1      Reo Speedwagon  I Want To Know What Love Is
# 2  Kris Kristofferson       The Eagle And The Bear
# 3                Kyla               I Feel For You
# 4          Kanye West                I'll Fly Away
# 5      Point Of Grace                      Any Way
# 6    Barbra Streisand                   I Like Him
# 7        Neil Diamond            Don't Turn Around
# 8        Idina Menzel         Better To Have Loved
# 9        Utada Hikaru                      Animato
#
#                                                 text  \
# 0  Well, you're my friend  \r\nAnd you can see  \...
# 1  I gotta take a little time  \r\nA little time ...
# 2  I will fight and I will die for freedom up aga...
# 3  Something inside,  \r\nMy heart,  \r\nAnd it f...
# 4  Some glad morning when this life is over  \r\n...
# 5  Setting out, what a child, my steps ahead of m...
# 6  I like him, I like him,  \r\nHow strange the f...
# 7  If you want to leave  \r\nI won't beg you to s...
# 8  Better To Have Loved  \r\nOoh  \r\nBetter To H...
# 9  Somebody out there better get this  \r\nNot ma...
#
#                                       processed_text
# 0  well youre friend see may times weve drinking ...
# 1  got ta take little time little time think thin...
# 2  fight die freedom eagle bear help brother well...
# 3  something inside heart feels like magic changi...
# 4  glad morning life ill fly away home gods celes...
# 5  setting child steps ahead mind doubt til knock...
# 6  like like strange feeling like never dreamed c...
# 7  want leave wont beg stay got ta go darlin mayb...
# 8  better loved ooh better loved ooh sun went tom...
# 9  somebody better get many people like speakers ...

# %% [markdown]
# **Tf-Idf and Cosine Similarity**

# %%
vectorizer = TfidfVectorizer(max_features=5000)
tfidf_matrix = vectorizer.fit_transform(df['processed_text'])

# %%
cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)

# %% [markdown]
# **Songs Recommendations**

# %%
def recommend_songs(song_title, cosine_sim=cosine_sim, num_recommendations=5):
    song_index = df[df['song'].str.lower() == song_title.lower()].index
    if len(song_index) == 0:
        return "Song not found in the dataset!"
    song_index = song_index[0]

    similarity_scores = list(enumerate(cosine_sim[song_index]))
    similarity_scores = sorted(similarity_scores, key=lambda x: x[1], reverse=True)
    similarity_scores = similarity_scores[1:num_recommendations+1]

    song_indices = [i[0] for i in similarity_scores]
    recommended_songs = df[['song', 'artist']].iloc[song_indices]
    return recommended_songs

# %%
songs = recommend_songs("Better To Have Loved")
print(songs)
# Out:
#                     song            artist
# 7077        Marble Halls              Enya
# 29       Better Together     Fifth Harmony
# 6678  Do You Feel Loved?                U2
# 6058      You Were Loved   Whitney Houston
# 9035   Isn't This Better  Barbra Streisand

# %%
songs = recommend_songs("love me like you do")
print(songs)
# Out:
#                                       song           artist
# 2463  Don't Let Him Take Your Love From Me  The Temptations
# 9471                             I Like It     Depeche Mode
# 9498                            I Love You      Chris Brown
# 5993             Love You Like A Love Song     Selena Gomez
# 5779                        Do You Love Me             Kiss

# %%
songs = recommend_songs("bad guy")
print(songs)
# Out:
# Song not found in the dataset!
